# %%
# !unzip -o Similar-Biclique-Idx-main.zip

# %%
# %cd Similar-Biclique-Idx-main

# %% [markdown]
# ## 步骤 2: 编译代码
# 编译数据转换工具 `edgelist2binary` 和主程序 `msbe`。

# %%
# %%bash
# g++ datasets/edgelist2binary.cpp -o edgelist2binary
# g++ -O3 main.cpp -o msbe

# %% [markdown]
# ## 步骤 3: 创建测试数据
# 创建一个简单的测试图文件 `g_test.txt`。

# %%
# %%writefile g_test.txt
# 2 3 5
# 0 2
# 0 3
# 1 2
# 1 3
# 1 4

# %% [markdown]
# ## 步骤 4: 运行程序
# 1. 将文本图转换为二进制格式。
# 2. 构建索引。
# 3. 运行查询。

# %%
# 1. 转换格式
# !./edgelist2binary g_test.txt

# %%
# 2. 构建索引 (bld_idx=1)
# !./msbe g_test.txt 1 1 0.3 GRL3 1 GRL3 0 0 heu 4 0.1 2 2

# %%
# 3. 运行查询 (bld_idx=0)
# !./msbe g_test.txt 0 1 0.3 GRL3 1 GRL3 0 0 heu 4 0.1 2 2
