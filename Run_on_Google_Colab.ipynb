# %%
# 4. 运行训练脚本
# %cd TSB_CL_Project

# 运行训练
# !python train.py

# %%
# 3. 编译 C++ 核心程序 (msbe)
import os

# 切换到 C++ 项目目录
# %cd Similar-Biclique-Idx-main

# 编译
# !g++ -O3 main.cpp -o msbe
# !chmod +x msbe

print("编译完成，msbe 可执行文件已生成。")
# %cd ..

# %%
# 2. 安装依赖
# !pip install -r TSB_CL_Project/requirements.txt

# %%
# 1. 克隆代码仓库
# 如果你的仓库是私有的，请在 URL 中加入 Token，格式为: https://<your_token>@github.com/yangzeha/ai_project.git
# 或者将仓库设为 Public 后直接克隆
# !git clone https://github.com/yangzeha/ai_project.git

# %cd ai_project
