# %%
# !git clone https://github.com/yangzeha/ai_project.git
# %cd ai_project

# %%
# %%bash
# cd Similar-Biclique-Idx-main
# g++ -O3 main.cpp -o msbe
# chmod +x msbe

# %%
import os
if not os.path.exists('TSB_CL_Project/datasets/yelp2018.txt'):
    print("Downloading dataset...")
    # !python TSB_CL_Project/prepare_yelp2018.py

# %%
# !python TSB_CL_Project/quick_proof_direct.py

# %%
from IPython.display import Image
Image(filename='comparison_results.png')
